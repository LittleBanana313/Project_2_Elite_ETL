# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import os
import sys

# Select file to preview
file = 'Listings'
path = f'../raw/{file}.csv'
bnb = pd.read_csv(path, low_memory=False)
bnb.head(5)
# Out:
#    listing_id                                              name   host_id  \
# 0      281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                        39 mÂ² Paris (Sacre CÅ“ur)  10328771
# 2     4082273               Lovely apartment with Terrace, 60m2  19252768
# 3     4797344               Cosy studio (close to Eiffel tower)  10668311
# 4     4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#    host_since                 host_location host_response_time  \
# 0   12/3/2011  Paris, Ile-de-France, France                NaN
# 1  11/29/2013  Paris, Ile-de-France, France                NaN
# 2   7/31/2014  Paris, Ile-de-France, France                NaN
# 3  12/17/2013  Paris, Ile-de-France, France                NaN
# 4  12/14/2014  Paris, Ile-de-France, France                NaN
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 NaN                   NaN                 f
# ...

# %%
# Filter by location
narrowdf = bnb.loc[(bnb["city"] == 'New York')]
narrowdf.head()
# Out:
#       listing_id                                 name   host_id  host_since  \
# 9220     3457770     Cute 1 BR in the Lower East Side   9604972  10/23/2013
# 9221     4173751      Lovely Apartment in Harlem West   9197440   10/2/2013
# 9222     4259427  Appartement en duplex de 3 chambres  21833312   9/27/2014
# 9223     4370230                                  NaN  22686810  10/18/2014
# 9224     5286096   Amazing Studio-EmpireStateBuilding   3866196  10/14/2012
#
#                      host_location host_response_time  host_response_rate  \
# 9220  Paris, Ile-de-France, France                NaN                 NaN
# 9221  Paris, Ile-de-France, France                NaN                 NaN
# 9222  Paris, Ile-de-France, France                NaN                 NaN
# 9223  Paris, Ile-de-France, France                NaN                 NaN
# 9224  Paris, Ile-de-France, France                NaN                 NaN
#
# ...

# %%
# Validate that we still have enough rows
len(narrowdf)
#output to csv and save
narrowdf.to_csv(r'../output/nyc_bnb_listings.csv', index=True)

# %%
# Select file to preview
data_location = '/Users/philliphenson/Desktop/ETL/NYC_crime.csv'
df = pd.read_csv(data_location)

# %%
df.shape
# Out:
# (3881989, 19)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'arrest_key', 'arrest_date', 'pd_desc', 'ofns_desc',
#        'law_code', 'law_cat_cd', 'age_group', 'perp_sex', 'perp_race',
#        'latitude', 'longitude', 'arrest_boro', 'arrest_precinct',
#        'jurisdiction_code', ':@computed_region_f5dn_yrer',
#        ':@computed_region_yeji_bk3q', ':@computed_region_92fq_4b7q',
#        ':@computed_region_sbqj_enih'],
#       dtype='object')

# %%
df
# Out:
#          Unnamed: 0  arrest_key arrest_date  \
# 0                 0   192799737  2019-01-26
# 1                 1   193260691  2019-02-06
# 2                 2   149117452  2016-01-06
# 3                 3   190049060  2018-11-15
# 4                 4    24288194  2006-09-13
# ...             ...         ...         ...
# 3881984     3881984    24592084  2006-10-01
# 3881985     3881985    24028282  2006-08-25
# 3881986     3881986    24036787  2006-08-26
# 3881987     3881987    24028407  2006-08-25
# 3881988     3881988    24321597  2006-09-14
#
#                                             pd_desc  \
# 0                                      SEXUAL ABUSE
# 1           CRIMINAL SALE OF A CONTROLLED SUBSTANCE
# 2                                            RAPE 3
# 3                                            RAPE 1
# 4                              TRESPASS 3, CRIMINAL
# ...                                             ...
# 3881984  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED
# ...

# %%
crime_1 = df

# %%
# drop unnecessary columns
crime_1 = crime_1.drop(columns={':@computed_region_f5dn_yrer', ':@computed_region_f5dn_yrer',
                    ':@computed_region_92fq_4b7q', ':@computed_region_sbqj_enih',
                    ':@computed_region_yeji_bk3q', 'Unnamed: 0'})
# crime_df.drop(columns=['full_arrest_boro'], axis=1)
crime_1
# Out:
#          arrest_key arrest_date                                     pd_desc  \
# 0         192799737  2019-01-26                                SEXUAL ABUSE
# 1         193260691  2019-02-06     CRIMINAL SALE OF A CONTROLLED SUBSTANCE
# 2         149117452  2016-01-06                                      RAPE 3
# 3         190049060  2018-11-15                                      RAPE 1
# 4          24288194  2006-09-13                        TRESPASS 3, CRIMINAL
# ...             ...         ...                                         ...
# 3881984    24592084  2006-10-01  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED
# 3881985    24028282  2006-08-25                       MARIJUANA, SALE 4 & 5
# 3881986    24036787  2006-08-26    PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4
# 3881987    24028407  2006-08-25            TRAFFIC,UNCLASSIFIED MISDEMEANOR
# 3881988    24321597  2006-09-14          CONTROLLED SUBSTANCE, POSSESSION 7
#
# ...

# %%
# copy one column for manipulation
full_arrest = crime_1['arrest_boro'].copy()
# insert that column into dataframe
crime_1.insert(12, "district", full_arrest)
# verify that it worked
crime_1
# Out:
#          arrest_key arrest_date                                     pd_desc  \
# 0         192799737  2019-01-26                                SEXUAL ABUSE
# 1         193260691  2019-02-06     CRIMINAL SALE OF A CONTROLLED SUBSTANCE
# 2         149117452  2016-01-06                                      RAPE 3
# 3         190049060  2018-11-15                                      RAPE 1
# 4          24288194  2006-09-13                        TRESPASS 3, CRIMINAL
# ...             ...         ...                                         ...
# 3881984    24592084  2006-10-01  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED
# 3881985    24028282  2006-08-25                       MARIJUANA, SALE 4 & 5
# 3881986    24036787  2006-08-26    PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4
# 3881987    24028407  2006-08-25            TRAFFIC,UNCLASSIFIED MISDEMEANOR
# 3881988    24321597  2006-09-14          CONTROLLED SUBSTANCE, POSSESSION 7
#
# ...

# %%
# discover unique boroughs
crime_1.arrest_boro.unique()
# Out:
# array(['M', 'K', 'B', 'Q', 'S'], dtype=object)

# %%
# Manhattan (M), Brooklyn (K), Queens (Q), The Bronx (B), and Staten Island (S): rename/replace col values
crime_1['district'] = crime_1['district'].map({'M': 'Manhattan', 'K': 'Brooklyn', 
                                               'B': 'Bronx', 'Q': 'Queens', 'S': 'Staten Island'})
# verify
crime_1
# Out:
#          arrest_key arrest_date                                     pd_desc  \
# 0         192799737  2019-01-26                                SEXUAL ABUSE
# 1         193260691  2019-02-06     CRIMINAL SALE OF A CONTROLLED SUBSTANCE
# 2         149117452  2016-01-06                                      RAPE 3
# 3         190049060  2018-11-15                                      RAPE 1
# 4          24288194  2006-09-13                        TRESPASS 3, CRIMINAL
# ...             ...         ...                                         ...
# 3881984    24592084  2006-10-01  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED
# 3881985    24028282  2006-08-25                       MARIJUANA, SALE 4 & 5
# 3881986    24036787  2006-08-26    PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4
# 3881987    24028407  2006-08-25            TRAFFIC,UNCLASSIFIED MISDEMEANOR
# 3881988    24321597  2006-09-14          CONTROLLED SUBSTANCE, POSSESSION 7
#
# ...

# %%
crime_1['pd_desc'].values.tolist()
# Out:
# ['SEXUAL ABUSE',
#  'CRIMINAL SALE OF A CONTROLLED SUBSTANCE',
#  'RAPE 3',
#  'RAPE 1',
#  'TRESPASS 3, CRIMINAL',
#  'RAPE 3',
#  'RAPE 1',
#  'SEXUAL ABUSE 3,2',
#  'SEXUAL ABUSE 3,2',
#  'ASSAULT 3',
#  'SEXUAL ABUSE 3,2',
#  'UNAUTHORIZED SALE OF TRANSPORTATION SERVICES',
#  'STRANGULATION 1ST',
#  'PROSTITUTION',
#  'SEXUAL ABUSE 1',
#  'SODOMY 1',
#  'WEAPONS POSSESSION 3',
#  'STRANGULATION 1ST',
#  'SEXUAL ABUSE 3,2',
#  'UNAUTHORIZED SALE OF TRANSPORTATION SERVICES',
#  'RAPE 1',
#  'RIOT 1',
#  'MARIJUANA, POSSESSION 1, 2 & 3',
#  'RAPE 3',
#  'IMPERSONATION 2, PUBLIC SERVANT',
#  'SEXUAL ABUSE 3,2',
#  'RAPE 3',
#  'SODOMY 3',
#  'STOLEN PROPERTY 3,POSSESSION',
#  'STRANGULATION 1ST',
#  'MARIJUANA, SALE 4 & 5',
#  'CONTROLLED SUBSTANCE, POSSESSION 7',
#  'UNAUTHORIZED SALE OF TRANSPORTATION SERVICES',
#  'RECKLESS ENDANGERMENT 1',
#  'FORGERY,ETC.,UNCLASSIFIED-FELONY',
#  'WEAPONS POSSESSION 3',
#  'MARIJUANA, POSSESSION 4 & 5',
#  'BURGLARY,RESIDENCE,NIGHT',
# ...

# %%
a = crime_1['pd_desc'].unique()
a
# Out:
# array(['SEXUAL ABUSE', 'CRIMINAL SALE OF A CONTROLLED SUBSTANCE',
#        'RAPE 3', 'RAPE 1', 'TRESPASS 3, CRIMINAL', 'SEXUAL ABUSE 3,2',
#        'ASSAULT 3', 'UNAUTHORIZED SALE OF TRANSPORTATION SERVICES',
#        'STRANGULATION 1ST', 'PROSTITUTION', 'SEXUAL ABUSE 1', 'SODOMY 1',
#        'WEAPONS POSSESSION 3', 'RIOT 1', 'MARIJUANA, POSSESSION 1, 2 & 3',
#        'IMPERSONATION 2, PUBLIC SERVANT', 'SODOMY 3',
#        'STOLEN PROPERTY 3,POSSESSION', 'MARIJUANA, SALE 4 & 5',
#        'CONTROLLED SUBSTANCE, POSSESSION 7', 'RECKLESS ENDANGERMENT 1',
#        'FORGERY,ETC.,UNCLASSIFIED-FELONY', 'MARIJUANA, POSSESSION 4 & 5',
#        'BURGLARY,RESIDENCE,NIGHT', 'WEAPONS POSSESSION 1 & 2',
#        'TRESPASS 2, CRIMINAL', 'RAPE 2',
#        'ROBBERY,UNCLASSIFIED,OPEN AREAS', 'FORGERY,ETC.-MISD.',
#        'MAKING A TERRORISTIC THREAT', 'ARSON 2,3,4', 'GRAND LARCENY',
#        'ASSAULT 2,1,UNCLASSIFIED', 'WEAPONS, POSSESSION, ETC',
#        'FORGERY\xa0', 'AGGRAVATED SEXUAL ABUSE',
# ...

# %%
df_new = crime_1[crime_1["pd_desc"].isin(['ASSAULT 3', 'STRANGULATION 1ST','ARSON 2,3,4', 'ASSAULT 2,1,UNCLASSIFIED', 'ASSAULT 2,1,PEACE OFFICER', 'PREDATORY SEXUAL ASSAULT AGAINST A CHILD','ASSAULT POLICE/PEACE OFFICER','MURDER,UNCLASSIFIED','RIOT 2/INCITING','ROBBERY,CAR JACKING','AGGRAVATED SEXUAL ASBUSE','TORTURE/INJURE ANIMAL CRUELTY','HOMICIDE,NEGLIGENT,UNCLASSIFIE','WEAPONS,MFR,TRANSPORT,ETC.', 'NEGLECT/POISON ANIMAL','CONFINING ANIMAL IN VEHICLE/SHELTER','ARSON 1','PREDATORY SEXUAL ASSAULT','COURSE OF SEXUAL CONDUCT AGAINST A CHILD','AGGRAVATED VEHICULAR HOMICIDE','ROBBERY,GAS STATION', 'MANSLAUGHTER,UNCLASSIFIED - NON NEGLIGENT', 'ROBBERY,CARJACKING OF MV OTHER THAN TRUCK','USE OF A CHILD IN A SEXUAL PERFORMANCE','HOMICIDE, NEGLIGENT, VEHICLE, INTOX DRIVER','HOMICIDE,NEGLIGENT,UNCLASSIFIED', 'ABORTION 1','PLACE FALSE BOMB','USE OF A CHEMICAL OR BIOLOGICAL WEAPON','WEAPONS,DISPOSITION OF','VEHICULAR ASSAULT (INTOX DRIVER)','INCOMPETENT PERSON,ENDANGERING WELFARE','WEAPONS,PROHIBITED USE','USING SLUGS, 2ND','PROMOTING SUICIDE ATTEMPT','HARMING A SERVICE ANIMAL','POSSESSION OF A CHEMICAL OR BIOLOGICAL WEAPON','WEAPONS,PROHIBITED USE IMITATION PISTOL','SUPP ACT TERRORISM 1','AGGRAVATED MANSLAUGHTER', 'ABORTION 2,1, SELF','ANARCHY,CRIMINAL','USE OF A CHILD TO COMMIT A CONTROLLED SUBSTANCE OFFENSE'])]
df_new
# Out:
#          arrest_key arrest_date                    pd_desc  \
# 9         189129210  2018-10-23                  ASSAULT 3
# 12        199836526  2019-07-16          STRANGULATION 1ST
# 17        201100692  2019-08-14          STRANGULATION 1ST
# 29        191717184  2019-01-01          STRANGULATION 1ST
# 41        189263596  2018-10-27                  ASSAULT 3
# ...             ...         ...                        ...
# 3881910    24236955  2006-09-10                  ASSAULT 3
# 3881912    24236566  2006-09-10  ASSAULT 2,1,PEACE OFFICER
# 3881935    24130052  2006-09-03                  ASSAULT 3
# 3881940    24347714  2006-09-17            RIOT 2/INCITING
# 3881953    24577795  2006-10-01                  ASSAULT 3
#
#                                            ofns_desc    law_code law_cat_cd  \
# 9                       ASSAULT 3 & RELATED OFFENSES  PL 1200000          M
# 12                                    FELONY ASSAULT  PL 1211200          F
# ...
